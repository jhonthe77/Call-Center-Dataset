# %%
import pandas as pd
import plotly.express as px

# %%
df_=pd.read_csv('Callcenter.csv')

# %%
df_
# Out:
#        Agente       Fecha  Hora               Tema Respondido (S/N) Resuelto  \
# 0       Diane  2021-01-01     9   Contract related                Y        Y
# 1       Becky  2021-01-01     9  Technical Support                Y        N
# 2     Stewart  2021-01-01     9   Contract related                Y        Y
# 3        Greg  2021-01-01     9   Contract related                Y        Y
# 4       Becky  2021-01-01    10    Payment related                Y        Y
# ...       ...         ...   ...                ...              ...      ...
# 4049  Stewart  2021-03-31    13          Streaming                Y        Y
# 4050      Jim  2021-03-31    16    Payment related                Y        Y
# 4051    Diane  2021-03-31    16    Payment related                Y        Y
# 4052    Diane  2021-03-31    16    Payment related                Y        Y
# 4053      Jim  2021-03-31    17          Streaming                Y        Y
#
# ...
